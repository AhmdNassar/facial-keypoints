# %%
import matplotlib.pyplot as plt
import torch
import torchvision
import random

# to re=load loaddata and helper if changes happened 
# %load_ext autoreload
# %autoreload 2
from torchvision import transforms
from torch.utils.data import DataLoader
from loaddata import FacialKeyPointsDataset , Rescale , Normalize
from helper import show_keypoints
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Test load data and helper

# %%
traindata = FacialKeyPointsDataset('data/training/',csv_file='data/training_frames_keypoints.csv')

# %%
print(len(traindata))
# Out:
# 3462

# %%
# try to load some images and display them
fig = plt.figure(figsize=(15,15))
for i in range(10):
    img , keypts = traindata[random.randint(0,3462)]
    ax = fig.add_subplot(5,2,i+1)
    show_keypoints(img,keypts)
# Out:
# E:\Programing\DeepLearning\projects\facial-keypoints\loaddata.py:38: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   keypoints = self.csv_file.iloc[idx][1::].as_matrix().astype('float32').reshape(-1,2)

# %%
#test Rescale
rescal = Rescale((255,255))
img , kep = (traindata[2])
show_keypoints(img,kep)
# Out:
# E:\Programing\DeepLearning\projects\facial-keypoints\loaddata.py:38: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   keypoints = self.csv_file.iloc[idx][1::].as_matrix().astype('float32').reshape(-1,2)

# %%
rescal = Rescale((255,255))
img , kep = rescal(traindata[2])
show_keypoints(img,kep)
# Out:
# E:\Programing\DeepLearning\projects\facial-keypoints\loaddata.py:38: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   keypoints = self.csv_file.iloc[idx][1::].as_matrix().astype('float32').reshape(-1,2)
